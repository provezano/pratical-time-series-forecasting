# %% [markdown]
# ## 3.0 Performance Evaluation

# %% [markdown]
# If we use the same data to develop the model and asses its performance, we introduce **bias**.

# %% [markdown]
# The "best" model can indeed have a superior performance, but the risk are that the aspects of the data happen to match the chosen model better than other models. This phenomenal is called overfitting. It means that the model is fitting the systematic **and** the noise part of the series. Therefore, it's unlikely to have a good performance on new unseen data.

# %% [markdown]
# ### 3.1 Data Partitioning

# %% [markdown]
# To tackle overfitting, we can split the data set in, usually, 2 (or 3) disjoint subsets that we'll discuss here.

# %% [markdown]
# #### 3.1.1 Cross-Sectional Data

# %% [markdown]
# The data is randomly splitted in tree disjoint datasets.
#
#    * training: data used to develop the models.
#    * validation: data used to assess the performance of each model, hyperparameter tuning and pick the best one.
#    * test: assess the performance of the chosen model with new data.

# %% [markdown]
# #### 3.1.2 Temporal Data

# %% [markdown]
# The data is **sequentially** splitted in two disjoint datasets.
#
#    * training: data used to develop the models.
#    * validation: data used to assess the performance of each model, hyperparameter tuning and pick the best one.
#
#     In the case of temporal data, the test set tends to cause more harm than benefit.

# %% [markdown]
# #### 3.1.3 Joining Partitions for Forecasting

# %% [markdown]
# After the validation and the choosing of the best model. It's a common practice to rebuild the model using the whole data. The benefits of recombining are:
#
#    * The validation data contains the most recent and (usually) the most valuable data.
#    * With more data, some models performs better.
#    * If only the training data is used, it's required to predict even more values in the future.

# %% [markdown]
# #### 3.1.4 Choosing the Validation Period

# %% [markdown]
# The main practice is to choose an evaluation period that mimics the forecast horizon.

# %% [markdown]
# ### Example with Amtrak dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/AmtrakPassengersMonthly T-Competition.xls', sheet_name='Data')
df.drop('Amtrak Ridership Number of Passengers ( in thousands)', axis=1, inplace=True)

# %% [markdown]
# ## Plot the dataset

# %%
sns.lineplot(x='Month', y='Ridership', data=df)
plt.show()

# %%
df.shape
# Out:
# (159, 2)

# %%
fixed.nValid <- 36
fixed.nTrain <- length(ridership.ts) - fixed.nValid
stepsAhead <- 1
error <- rep(0, fixed.nValid - stepsAhead + 1)
percent.error <- rep(0, fixed.nValid - stepsAhead + 1)
for(j in fixed.nTrain:(fixed.nTrain + fixed.nValid - stepsAhead)) {
train.ts <- window(ridership.ts, start = c(1991, 1), end = c(1991, j))
valid.ts <- window(ridership.ts, start = c(1991, j + stepsAhead), end = c(1991, j + stepsAhead))
naive.pred <- naive(train.ts, h = stepsAhead)
error[j - fixed.nTrain + 1] <- valid.ts - naive.pred$mean[stepsAhead]
percent.error[j - fixed.nTrain + 1] <- error[j - fixed.nTrain + 1] / valid.ts
}
mean(abs(error))
sqrt(mean(error^2))
mean(abs(percent.error))

# %%
df_valid
# Out:
# Empty DataFrame
# Columns: [Month, Ridership]
# Index: []

# %%
num_valid = 36
num_train = df.shape[0] - num_valid
steps_ahead = 1
error = [0]*(num_valid - steps_ahead + 1)
percent_error = [0]*(num_valid - steps_ahead + 1)

for j in range(num_train, num_train + num_valid - steps_ahead, 1):
    
    df_train = df.iloc[:j]
    df_valid = df.iloc[j+steps_ahead:j+steps_ahead]
    
    naive_pred = df_train.iloc[-steps_ahead]
    
    error[j - num_train + 1] = (df_valid['Ridership'] - naive_pred['Ridership']).mean()
    percent_error[j - num_train + 1] = error[j - num_train + 1]  / df_valid['Ridership']
    

print(np.mean(np.abs(error)))
print(np.sqrt(np.mean([e**2 for e in error])))
print(np.mean(np.abs(percent_error)))
# Out:
# nan
# nan
# []
# <ipython-input-37-f5fc4a5e6717>:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(np.mean(np.abs(percent_error)))

# %%
num_valid = 36
num_train = df.shape[0] - num_valid
steps_ahead = 2
error = [0]*(num_valid - steps_ahead + 1)
percent_error = [0]*(num_valid - steps_ahead + 1)

for j in range(num_train, num_train + num_valid - steps_ahead, 1):
    df_train = df.iloc[:j]
    df_valid = df.iloc[j:j+steps_ahead+1]
    break

# %%
df_train
# Out:
#          Month  Ridership
# 0   1991-01-01   1708.917
# 1   1991-02-01   1620.586
# 2   1991-03-01   1972.715
# 3   1991-04-01   1811.665
# 4   1991-05-01   1974.964
# ..         ...        ...
# 119 2000-12-01   2000.153
# 120 2001-01-01   1683.148
# 121 2001-02-01   1663.404
# 122 2001-03-01   2007.928
# 123 2001-04-01   2023.792
#
# [124 rows x 2 columns]

# %%
df_valid
# Out:
#          Month  Ridership
# 124 2001-05-01   2047.008
# 125 2001-06-01   2072.913

# %%
np.mean([2047.008-2023.792, 2072.913-2023.792])
# Out:
# 36.16850000000011

# %%
np.mean((-23.216000000000122, 25.904999999999973))
# Out:
# 1.3444999999999254

# %%
j- num_train+1
# Out:
# 35

# %%
error[35]
# Out:
# 294.4399999999998

# %%
def naive(series, h=1):
    num = series.iloc[-1]
    return [num]*h

# %%
df_train

# %%
df_valid
# Out:
#          Month  Ridership
# 158 2004-03-01   2132.446

# %%
num_valid = 36
num_train = df.shape[0] - num_valid
steps_ahead = 1
error = [0]*(num_valid - steps_ahead + 1)
percent_error = [0]*(num_valid - steps_ahead + 1)
predicted = []
for j in range(num_train, num_train + num_valid - steps_ahead + 1, 1):
    df_train = df.iloc[:j]
    df_valid = df.iloc[j:j+steps_ahead]

    naive_pred = naive(df_train['Ridership'], h=steps_ahead)
    predicted.append([df_valid['Month'].iloc[0], np.mean(naive_pred)])
    
    error[j - num_train] = np.mean(df_valid['Ridership'].iloc[:steps_ahead]-naive_pred)
    percent_error[j - num_train] = error[j - num_train]/df_valid['Ridership'].iloc[:steps_ahead]
    #break;
np.mean(np.abs(error)), np.sqrt(np.mean(np.power(error,2))), np.mean(np.abs(percent_error))
# Out:
# (119.42888888888888, 169.17326606306457, 0.062060660975044736)

# %%
num_valid = 36
num_train = df.shape[0] - num_valid
steps_ahead = 1
error = [0]*(num_valid - steps_ahead + 1)
percent_error = [0]*(num_valid - steps_ahead + 1)
predicted = []
for j in range(num_train, num_train + num_valid - steps_ahead + 1, 1):
    df_train = df.iloc[:j]
    df_valid = df.iloc[j:j+steps_ahead]

    naive_pred = snaive(df_train['Ridership'], h=steps_ahead)
    predicted.append([df_valid['Month'].iloc[0], np.mean(naive_pred)])
    
    error[j - num_train] = np.mean(df_valid['Ridership'].iloc[:steps_ahead]-naive_pred)
    percent_error[j - num_train] = error[j - num_train]/df_valid['Ridership'].iloc[:steps_ahead]
    #break;
np.mean(np.abs(error)), np.sqrt(np.mean(np.power(error,2))), np.mean(np.abs(percent_error))

# %%
df_train.shape[0], df.shape[0]-df_train.shape[0]
# Out:
# (123, 36)

# %%
np.mean(error)
# Out:
# 3.0181666666666667

# %%
error
# Out:
# [23.216000000000122,
#  25.904999999999973,
#  53.80400000000009,
#  75.92099999999982,
#  -494.94499999999994,
#  243.0229999999999,
#  22.89800000000014,
#  11.115000000000009,
#  -225.10000000000014,
#  10.966000000000122,
#  249.317,
#  28.486000000000104,
#  20.36499999999978,
#  -74.49599999999987,
#  80.99099999999976,
#  -48.697999999999865,
#  -292.405,
#  182.61599999999999,
#  -58.42599999999993,
#  138.00700000000006,
#  -218.3190000000002,
#  -28.54399999999987,
#  316.97699999999986,
#  32.43299999999999,
#  6.012000000000171,
#  24.759999999999764,
#  93.67800000000034,
#  -48.98900000000003,
#  -242.95400000000018,
#  190.06399999999985,
#  -45.41599999999971,
#  64.62300000000005,
#  -309.1690000000001,
#  6.498000000000047,
#  294.4399999999998,
#  0]

# %%
percent_error
# Out:
# [124    0.011341
#  Name: Ridership, dtype: float64,
#  125    0.012497
#  Name: Ridership, dtype: float64,
#  126    0.025299
#  Name: Ridership, dtype: float64,
#  127    0.034468
#  Name: Ridership, dtype: float64,
#  128   -0.289833
#  Name: Ridership, dtype: float64,
#  129    0.124581
#  Name: Ridership, dtype: float64,
#  130    0.011602
#  Name: Ridership, dtype: float64,
#  131    0.0056
#  Name: Ridership, dtype: float64,
#  132   -0.127925
#  Name: Ridership, dtype: float64,
#  133    0.006193
#  Name: Ridership, dtype: float64,
#  134    0.12343
#  Name: Ridership, dtype: float64,
#  135    0.013906
#  Name: Ridership, dtype: float64,
#  136    0.009844
#  Name: Ridership, dtype: float64,
#  137   -0.037355
#  Name: Ridership, dtype: float64,
#  138    0.039027
#  Name: Ridership, dtype: float64,
#  139   -0.02403
#  Name: Ridership, dtype: float64,
#  140   -0.168615
#  Name: Ridership, dtype: float64,
#  141    0.095273
#  Name: Ridership, dtype: float64,
#  142   -0.03144
#  Name: Ridership, dtype: float64,
#  143    0.06913
#  Name: Ridership, dtype: float64,
#  144   -0.122787
#  Name: Ridership, dtype: float64,
#  145   -0.016316
#  Name: Ridership, dtype: float64,
#  146    0.153391
#  Name: Ridership, dtype: float64,
#  147    0.015452
#  Name: Ridership, dtype: float64,
#  148    0.002856
#  Name: Ridership, dtype: float64,
#  149    0.011626
#  Name: Ridership, dtype: float64,
#  150    0.042134
#  Name: Ridership, dtype: float64,
#  151   -0.02253
#  Name: Ridership, dtype: float64,
#  152   -0.125791
#  Name: Ridership, dtype: float64,
#  153    0.089591
#  Name: Ridership, dtype: float64,
#  154   -0.021876
#  Name: Ridership, dtype: float64,
#  155    0.030188
#  Name: Ridership, dtype: float64,
#  156   -0.168806
#  Name: Ridership, dtype: float64,
#  157    0.003535
#  Name: Ridership, dtype: float64,
#  158    0.138076
#  Name: Ridership, dtype: float64,
#  0]

# %%
df_predicted = pd.DataFrame(predicted).rename(columns={0:'Month', 1:'Ridership'})

# %%
df_final = pd.merge(df, df_predicted, how='left', on='Month')
df_final['Ridership_y'] = df_final.apply(lambda x: x['Ridership_x'] if pd.isnull(x['Ridership_y']) else x['Ridership_y'], axis=1)

df_final = df_final.melt('Month', var_name='cols',  value_name='vals')
g = sns.lineplot(x="Month", y="vals", hue='cols', data=df_final)
plt.show()

# %%
df_final
# Out:
#          Month  Ridership_x  Ridership_y
# 0   1991-01-01     1708.917     1708.917
# 1   1991-02-01     1620.586     1620.586
# 2   1991-03-01     1972.715     1972.715
# 3   1991-04-01     1811.665     1811.665
# 4   1991-05-01     1974.964     1974.964
# ..         ...          ...          ...
# 154 2003-11-01     2076.054     2121.470
# 155 2003-12-01     2140.677     2076.054
# 156 2004-01-01     1831.508     2140.677
# 157 2004-02-01     1838.006     1831.508
# 158 2004-03-01     2132.446     1838.006
#
# [159 rows x 3 columns]

# %%
df_final = df_final.melt('Month', var_name='cols',  value_name='vals')
g = sns.catplot(x="Month", y="vals", hue='cols', data=df_final, kind='point')
# Out:
# <ipython-input-156-4e383bd876fa>:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_final = df_final.melt('Month', var_name='cols',  value_name='vals')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-4e383bd876fa> in <module>
#       1 df_final = df_final.melt('Month', var_name='cols',  value_name='vals')
# ----> 2 g = sns.catplot(x="Month", y="vals", hue='cols', data=df_final, kind='point')
#
# C:\anaconda3\envs\ds\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\anaconda3\envs\ds\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# C:\anaconda3\envs\ds\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# C:\anaconda3\envs\ds\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1350     elif require_numeric and "numeric" not in (x_type, y_type):
#    1351         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1352         raise TypeError(err)
#    1353
#    1354     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
(2047.008-2023.792),(2072.913-2023.792)
# Out:
# (23.216000000000122, 49.121000000000095)

# %%
np.mean([(2047.008-2023.792),(2072.913-2023.792)])
# Out:
# 36.16850000000011

# %%
naive_pred
# Out:
# 2023.792

# %%
error
# Out:
# [0,
#  23.216000000000122,
#  25.904999999999973,
#  53.80400000000009,
#  75.92099999999982,
#  -494.94499999999994,
#  243.0229999999999,
#  22.89800000000014,
#  11.115000000000009,
#  -225.10000000000014,
#  10.966000000000122,
#  249.317,
#  28.486000000000104,
#  20.36499999999978,
#  -74.49599999999987,
#  80.99099999999976,
#  -48.697999999999865,
#  -292.405,
#  182.61599999999999,
#  -58.42599999999993,
#  138.00700000000006,
#  -218.3190000000002,
#  -28.54399999999987,
#  316.97699999999986,
#  32.43299999999999,
#  6.012000000000171,
#  24.759999999999764,
#  93.67800000000034,
#  -48.98900000000003,
#  -242.95400000000018,
#  190.06399999999985,
#  -45.41599999999971,
#  64.62300000000005,
#  -309.1690000000001,
#  6.498000000000047,
#  294.4399999999998]

# %%
df_train.tail()
# Out:
#          Month  Ridership
# 152 2003-09-01   1931.406
# 153 2003-10-01   2121.470
# 154 2003-11-01   2076.054
# 155 2003-12-01   2140.677
# 156 2004-01-01   1831.508

# %%
df_valid.head()
# Out:
#          Month  Ridership
# 158 2004-03-01   2132.446

# %%
2007.928-2047.008
# Out:
# -39.07999999999993

# %%
error
# Out:
# 39.07999999999993
